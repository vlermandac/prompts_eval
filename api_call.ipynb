# %% [markdown]
# ## Preliminaries

# %%
# Dependencies
import pickle
import json
from openai import OpenAI
import numpy as np
import os
import pandas as pd
import time

# %%
# Assume you have a file named 'example.pkl' containing a pickled object
with open('ssdh_all_raw_message', 'rb') as file:
    # Load the pickled object back into Python
    unpickled_object = pickle.load(file)

# The client for the API
client = OpenAI()

# %%
# Document slicing
documents = []
for i in range(0, int(len(unpickled_object)/2)):
    documents.append(unpickled_object[2*i])

# %% [markdown]
# ## Single prompt test for the API

# %%
# Original, non-modified prompt
prompt_file = open('prompts/original.txt','r').read()

# Assistant creation
assistant = client.beta.assistants.create(
    name="Chilean History Expert",
    instructions=prompt_file,
    model="gpt-4" # gpt-4 turbo is x2 times exprensive
)

# %%
# 'Conversation thread' creation
thread = client.beta.threads.create()

# Single message added
msg = client.beta.threads.messages.create(
    thread_id=thread.id,
    role="user",
    content=documents[19]
)

# Run the model
run = client.beta.threads.runs.create(
  thread_id=thread.id,
  assistant_id=assistant.id,
)

# %%
# Check if the run is completed
run = client.beta.threads.runs.retrieve(
  thread_id=thread.id,
  run_id=run.id
)
print(run.status)
# Out:
# completed

# %%
messages = client.beta.threads.messages.list(
  thread_id=thread.id
)
messages.data[0].content[0].text.value
# Out:
# SyncCursorPage[ThreadMessage](data=[ThreadMessage(id='msg_2xs5MBcLdvOVrOdEoG4Wo5Pl', assistant_id='asst_OnVlScN4AOSqVpRvDSA0gLZ4', content=[MessageContentText(text=Text(annotations=[], value="{'Gregorio BRAVO Ponce de Leon': [('Position within prison', 'Member of the Well-being Committee responsible for improving detention conditions'), ('Location', 'Held in the prison characterized by overcrowding, insufficient hygienic conditions and insufficient medical attention, particularly in case of emergencies')],\n 'Carlos RIOS Fuentes': [('Position within prison', 'Member of the Well-being Committee responsible for improving detention conditions'), ('Location', 'Held in the prison characterized by overcrowding, insufficient hygienic conditions and insufficient medical attention, particularly in case of emergencies')],\n 'German CALLEJAS Guerrero': [('Position within prison', 'Member of the Well-being Committee responsible for improving detention conditions'), ('Location', 'Held in the prison characterized by overcrowding, insufficient hygienic conditions and insufficient medical attention, particularly in case of emergencies')]}"), type='text')], created_at=1706205379, file_ids=[], metadata={}, object='thread.message', role='assistant', run_id='run_IurI7y67lgk8u5OBWmgmZqg4', thread_id='thread_SebfrvAqGX0An3WyrCmbUR6F'), ThreadMessage(id='msg_vqtUS6TJasz7HzfYOV0KzvGh', assistant_id=None, content=[MessageContentText(text=Text(annotations=[], value='Trato y disciplina: Los detenidos de las galerías 5 y 6 se han organizado, eligiendo\na un Comite de Bienestar, integrado por los señores Gregorio BRAVO Ponce de\nLeon, Carlos RIOS Fuentes y German CALLEJAS Guerrero. El trabajo del mismo\nComité consiste en mejorar, en colaboración con las Autoridades de la Car-\ncel, las condiciones de detención, o sea coordinar las distintas obras de\nmejoras, velar por las condiciones higiénicas y administrar un pequeflo fondo\ndestinado a sufragar las mejoras mas urgentes, Con ocasión de su visita, los\ndelegados del CICR entregaron 2 20.000 para dicho fondo, mantenido por los\nde tenidos mismos bajo las supervisiones del señor Alcaide.\nEl referido Comité dispone de un llamado "Libro de Control de Cargas Fisca-\nles", que sirve para controlar todos los aportes de la Cruz Roja.\n1 trato sigue siendo normal dentro del recinto carcelario.\nEn cuanto a los incomunicados, los delegados no pueden afirmarlo, porque\nlas costumbres del CICH.\nlas Autoridades rehusaron la entrevista a solas con ellos, contrariamente a\nEs de señalarse que entre los detenidos a disposicion de las Autoridades\nMilitares hay delincuentes comunes reincidentes. Tal hecho es contrario a\nlas costumbres penitenciarias y no deja de provocar problemas de disciplina.\nVarios detenidos recien llegados del Campo de Tejas Verdes se quejaron de\nmalos tratos sufridos en dicho lugar, durante interrogatorios. \nLos \ndelegados\npudieron comprobar contusiones abdominales y toracicas, \nuñas arrancadas,\ndientes quebrados, desprendimiento de la retina\n.\nConclusiones: Las condiciones de hacinamiento siguen siendo inaceptables.\nLas condiciones higiénicas son insuficientes, así como la atención médica,\nsobre todo en caso de emergencia.\nAsistencia del CICR : En marzo de 1974, los mismos delegados entregaron :\n30 baldes plásticos sin tapa\n15 escobillones\n2 galones de pintura blanca al óleo\n1 brocha gorda\nherramientas\nL\nmaquina y tijeras para cortar el pelo\n1 cortina de plástico\n2 pelotas: 1 de baby-futbol y 1 de basquetbol\n3 paletas y 12 pelotas de ping pong\n- 5 ajedrez\nA\n2458-24 MA 1974\n'), type='text')], created_at=1706205377, file_ids=[], metadata={}, object='thread.message', role='user', run_id=None, thread_id='thread_SebfrvAqGX0An3WyrCmbUR6F')], object='list', first_id='msg_2xs5MBcLdvOVrOdEoG4Wo5Pl', last_id='msg_vqtUS6TJasz7HzfYOV0KzvGh', has_more=False)

# %% [markdown]
# ## Prompt engineering tactics
# The idea is to follow some of the [strategies given by OpenAI](https://platform.openai.com/docs/guides/prompt-engineering) for getting better results using prompt engineering.
# The original prompt will be used as a base.

# %% [markdown]
# ### Write clear instructions
# 1. Let the model guess as little as possible.
# 2. Step-by-step instructions (also trying the 'magical' sentence [Take a deep breath and work on this problem step-by-step](https://arxiv.org/pdf/2309.03409.pdf)).
# ### Split complex tasks into simpler subtasks
# 3. Recursively summarize and clean text.
# ### Give the model time to "think"
# 4. Ask if there are any relevant info that was left behind. Tell them to not repeat info.
# (ex. Are there more relevant excerpts? Take care not to repeat excerpts. Also ensure that excerpts contain all relevant context needed to interpret them - in other words don't extract small snippets that are missing important context.)

# %% [markdown]
# ### TBA
# #### Use external tools
# - APIs.
# - Functions.
# #### Test changes systematically
# - [https://github.com/openai/evals/tree/main]
# - [https://www.deeplearning.ai/short-courses/automated-testing-llmops/]

# %% [markdown]
# ## Prompts description
# Row 0 correspond to the different prompts written in the './prompts' directory.
#
# Column 0 corresond to the strategies presented above, each represented with their respective number.
# |    | var1 | var2 | var3 | var4 | var5 | var6 | var7 | var8 |
# |----|------|------|------|------|------|------|------|------|
# | (1)|  ✅  |  ✅   | ✅   | ✅   | ✅   | ✅   | ✅   | ✅  |
# | (2)|  -   |  ✅  |  -   |  ✅   | -   | - | ✅   | ✅ |
# | (3)| -   | -   | ✅   |  ✅  | - | ✅   | -   | ✅   |
# | (4)| -   | -   | -   |  -  | ✅   | ✅   | ✅   | ✅   |

# %%
# 3, 5, 11, 17, 19 will be used as sample for manual evaluation
# document 17 gets no result from the original prompt (added on purpose)
documents_sample = []
for i in [3, 5, 11, 17, 19]:
    documents_sample.append(documents[i])

directory = "./prompts/"
prompts = []
for prompt in os.listdir(directory):
    with open(os.path.join(directory, prompt), 'r', encoding='utf-8') as file:
        prompts.append(file.read())

# %%
def results_to_df(prompts_batch, data_samples, openai_client):

    df = pd.DataFrame(columns=['prompt', 'document', 'result']) # df to return

    for prompt_idx, prompt in enumerate(prompts_batch):

        assistant = openai_client.beta.assistants.create(
            name="Chilean History Expert",
            instructions=prompt,
            model="gpt-4"
        )

        for doc_idx, doc in enumerate(data_samples):
            thread = openai_client.beta.threads.create()
            print(f"new thread created with id: {thread.id}.")

            m = openai_client.beta.threads.messages.create(
                thread_id=thread.id,
                role="user",
                content=doc
            )
            print(f"new message created with id: {m.id}.")

            run = openai_client.beta.threads.runs.create(
                thread_id=thread.id,
                assistant_id=assistant.id,
            )

            print(f"run instance created with id: {run.id}.")

            # wait while the assistant completes the answer
            run_status = ''
            while run_status != 'completed':
                print(f"run status: {run_status}.")
                run_status = openai_client.beta.threads.runs.retrieve(
                    thread_id=thread.id,
                    run_id=run.id
                ).status
                time.sleep(3)
            print(f"run status: {run_status}.")

            # assistant answer
            msg = openai_client.beta.threads.messages.list(
                thread_id=thread.id
            ).data[0].content[0].text.value

            # append row to df
            row = {'prompt' : prompt_idx, 'document' : doc_idx, 'result' : msg}
            df = pd.concat([df, pd.DataFrame.from_records([row])])
            print(f"Document {doc_idx} done.")

        print(f"Prompt {prompt_idx} done.")

    return df

# %%
df_results = results_to_df(prompts, documents_sample, client)
df_results
# Out:
# new thread created with id: thread_NAasKK5WtoaAd2JOkIZIACHk.
# new message created with id: msg_84UtpDl5NL4zy7sUkOo86JVI.
# run instance created with id: run_G9WG1a383PxDS6glNAUxmzX3.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# Document 0 done.
# new thread created with id: thread_rkSs7dVhSsWrkDAm0AIp8JgB.
# new message created with id: msg_hAsAaPBF6v0NzTlGmMdDwcLj.
# run instance created with id: run_AcnWvZP9jLUjOIxlk5jbJKDV.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# Document 1 done.
# new thread created with id: thread_NO5sgLCdzHlfzhMH5J5ol1Ds.
# new message created with id: msg_bJakTUfTXmasvAzruCa5Pwqd.
# run instance created with id: run_IU2aOAWvfpj4GmSZlLLB2JST.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# Document 2 done.
# new thread created with id: thread_Mua2phKpE6BBVJKUJh67dt8C.
# new message created with id: msg_ZEfI219KcDLh8RHfXw4GzT8M.
# run instance created with id: run_RMImmV11DfaxO0Ty6DjgtG9h.
# run status: .
# run status: in_progress.
# run status: in_progress.
# Document 3 done.
# new thread created with id: thread_e6Tg4gk2vaIhT0BbuA9N6RTL.
# new message created with id: msg_55NCGeWoKQgAL7oPLHxo8f6u.
# run instance created with id: run_49eXuRBl4p7Vjl5ZmbeyeJa6.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# Document 4 done.
# Prompt 0 done.
# new thread created with id: thread_2GvNuow8tKYWOTJW2iMIZxEX.
# new message created with id: msg_LtcNYEloxtbH6JzDmmXQHanr.
# run instance created with id: run_ETZiOoBEqVeW6dmWLg8y5i7E.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# Document 0 done.
# new thread created with id: thread_rS2z1YEVJwC9bixQ826fOU5d.
# new message created with id: msg_lERjXHNVPFzlr8fX69CcC1VW.
# run instance created with id: run_vkFzOxnZ6A2YPO8AIWF4gMhI.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# Document 1 done.
# new thread created with id: thread_CZJM2qOFmUQ46PZKKvbFrRCG.
# new message created with id: msg_M9RHtTfHZs4RdwRo7XRxwa2u.
# run instance created with id: run_MdUCG4BNfbWRSwip1IUb3tSo.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# Document 2 done.
# new thread created with id: thread_P6D7vx5Oe7B7f7De5Cq7tVoR.
# new message created with id: msg_djzDUPeYG4cP9KN4pI6T2N2E.
# run instance created with id: run_BNx0rxYGgUTXlxMVvqhkfsZ7.
# run status: .
# run status: in_progress.
# run status: in_progress.
# Document 3 done.
# new thread created with id: thread_STrET22gBrPfor4kBCtRxI4V.
# new message created with id: msg_Bw2yVvpPOpvCo8SevVy7jSTX.
# run instance created with id: run_1pa8cZiyXWkTNfG4VA2qjvnD.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# Document 4 done.
# Prompt 1 done.
# new thread created with id: thread_95pxmHvCuZ6QJeb3tfPDFucr.
# new message created with id: msg_WXZhLx55IBh0Prwr12UJLllv.
# run instance created with id: run_KDB7pIJ2HrHNrRDedmKSMjSv.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# Document 0 done.
# new thread created with id: thread_99A6BhwseJLDUyMPNA21OlaE.
# new message created with id: msg_vN6bJfVOOwFqxWXNLtLn9CTc.
# run instance created with id: run_oV0Ys9TStP7uXhwIUNOKk4ED.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# Document 1 done.
# new thread created with id: thread_qvM8fXCUArheEn1ak0GByXyx.
# new message created with id: msg_pAXHQPOYWxsqpJCiY5PpwH7U.
# run instance created with id: run_tlIWpqE5rsnq6wbJEzkzXXEH.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# Document 2 done.
# new thread created with id: thread_L8kBXf6twj9Xrnp5BibnmLu6.
# new message created with id: msg_B4H3HpeqthP5QTP3NjxJ9gW3.
# run instance created with id: run_QoWSV4IvrcqnHwzhZMVkRmge.
# run status: .
# run status: in_progress.
# run status: in_progress.
# Document 3 done.
# new thread created with id: thread_0fouysyc4QIbHAg62VmCVBzF.
# new message created with id: msg_rcYbOPXwf2q58b5CihgkF0OZ.
# run instance created with id: run_qUTPk8uHgyq0VM8pV2QxDaCO.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# Document 4 done.
# Prompt 2 done.
# new thread created with id: thread_ySVncyJW431MVyFLGfkxac0G.
# new message created with id: msg_46X9VPmHK2xDWYv4kZElfcxS.
# run instance created with id: run_rlcO6F4NI6u8uqotJfOFKOTe.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# Document 0 done.
# new thread created with id: thread_opKLYwYr6dd3Xbut9ncfaZ63.
# new message created with id: msg_i29TFzF8wyDhuIdJjZaYMT9J.
# run instance created with id: run_sHFiu7kOsiMBTgGHee5VzOlB.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# Document 1 done.
# new thread created with id: thread_GnJilq9hZz99Oyv8myw0Hvnz.
# new message created with id: msg_xxq0o2iJkQktjvT3eY81KEH8.
# run instance created with id: run_yZZU3zskfYaextsRGBJh8xaz.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# Document 2 done.
# new thread created with id: thread_8HSFFfDafgaGhhf5HbBRNRzI.
# new message created with id: msg_9lGN1eyeHEKZL8KU6UZQWN9Q.
# run instance created with id: run_P5gryzQBG67OjyQMWO2Q3jLe.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# Document 3 done.
# new thread created with id: thread_EERINCXJhJ9plhRpqQMHZyEP.
# new message created with id: msg_uKxXXPswBQhXhJ0yLh9OYWl4.
# run instance created with id: run_bOGgiQlqAYavLPWOmxQ7Knv9.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# Document 4 done.
# Prompt 3 done.
# new thread created with id: thread_ExYfjfTi7gaIMSlNUXT7B1vH.
# new message created with id: msg_fjWXKtUoq0iWNMRYLOOBTjT5.
# run instance created with id: run_2OzJfhQFtYtlfq57pZbyz1iO.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# Document 0 done.
# new thread created with id: thread_iTRxyefg5yFFS02ExFqxjVcG.
# new message created with id: msg_WdY3S8gNh5qMXlDCOH03GTrm.
# run instance created with id: run_KSX3ibttGxvVADaNgo7XbICj.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# Document 1 done.
# new thread created with id: thread_zC9iuLvn8tZ9AZgGdHbKYSzi.
# new message created with id: msg_O29WLl5IHUIg57X2j69Nm3K4.
# run instance created with id: run_KZEA1yAmEf9caTkQ5W0DBdgD.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# Document 2 done.
# new thread created with id: thread_gkcGHDmda87r65M0NnI0LTn9.
# new message created with id: msg_mcffVYOuDjdw70YyZG8AkDZh.
# run instance created with id: run_p5sLp4yrdhxpIEhhFCmWkzky.
# run status: .
# run status: in_progress.
# run status: in_progress.
# Document 3 done.
# new thread created with id: thread_XOpvOkf3lq9EGMARmjQDiBKj.
# new message created with id: msg_jBGkC2Znik6ACHolach7ONcA.
# run instance created with id: run_4XtIZi0YxL1A4p9BSQiCoIrq.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# Document 4 done.
# Prompt 4 done.
# new thread created with id: thread_6b0RDhXVgX3dorUuid5Sn4N1.
# new message created with id: msg_ZhF9vdxNsLsIMdzkVGZCBhNB.
# run instance created with id: run_RXRP0Tgl6geiPitBtXse9zVR.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# Document 0 done.
# new thread created with id: thread_KRcern0jQPVowZFNdEe9eifP.
# new message created with id: msg_DUAgICHOnprd1U2gDAj2qHV4.
# run instance created with id: run_ldVLzUcHQIidKvCBlnQ4swkI.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# Document 1 done.
# new thread created with id: thread_mfLf7JkOKQlvsPojopsikKh7.
# new message created with id: msg_rQhvkhGquzXi1H27FIZCJdQR.
# run instance created with id: run_Vd7RVyhuyK0tKjIpJrFrQGB0.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# Document 2 done.
# new thread created with id: thread_uGjR3jvpvwLSwHD7pRpFYC1B.
# new message created with id: msg_ra3KBvajnSOIVFkAtgVPhkOI.
# run instance created with id: run_athHRoVLZGd3gJ4JMB5vfmSr.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# Document 3 done.
# new thread created with id: thread_MpSKTB4G46RioGmKZqMnh0OK.
# new message created with id: msg_F4If7PepuGFQixbwsPgwaYVE.
# run instance created with id: run_SkQtw1b9drcTiehEqyg2Ur9x.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# Document 4 done.
# Prompt 5 done.
# new thread created with id: thread_1s2rapEbl5QB53R0qKrkmy9I.
# new message created with id: msg_OYgooiCum1sWcGYToJ4JiSo3.
# run instance created with id: run_3DEZarpHUFpaFdvGMQ8CGLJP.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# Document 0 done.
# new thread created with id: thread_CzSSLYXAVLNlBSMCiq9eo77g.
# new message created with id: msg_6dgC3AeuJ5NNyaRDTTSGgbP3.
# run instance created with id: run_rDqpI9lADP8pbx9fJl7jBFEx.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# Document 1 done.
# new thread created with id: thread_BRcMoOII4DfwQ1eLtd5mnqFN.
# new message created with id: msg_MKBN2h4Sq1JdVliubLA73L7C.
# run instance created with id: run_qUKNEdhc0rwkrVJnJLztqDDO.
# run status: .
# run status: in_progress.
# run status: in_progress.
# Document 2 done.
# new thread created with id: thread_ZzrBWH568XXHhsVYL4mU0RWS.
# new message created with id: msg_8zpvvyOHSAxtunJIUszcT8px.
# run instance created with id: run_lNPDtTaHu17sFnaeHuDX2yWs.
# run status: .
# run status: in_progress.
# run status: in_progress.
# Document 3 done.
# new thread created with id: thread_LGTr6uAus9XVT7j3Z3O9ywlp.
# new message created with id: msg_POYiOrLveIwrkwPp2WP8FtD6.
# run instance created with id: run_f3NZKw7NtIxrJSqxkYIH32KF.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# Document 4 done.
# Prompt 6 done.
# new thread created with id: thread_Kk0nIDQm9viJN5iSlsEkheBB.
# new message created with id: msg_ux4kPVUZXIijanqYT0euEtk6.
# run instance created with id: run_fy72LBQnEAt2A2gSUl1jbTp0.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# Document 0 done.
# new thread created with id: thread_OIOTdbJNy9IeKNSjazyG5Wju.
# new message created with id: msg_KguvyZsdmNdmRlWMvngk1qtV.
# run instance created with id: run_cTDNBBA1J4YPO3OyHfyutwVf.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# Document 1 done.
# new thread created with id: thread_3iTh7buZMYcDekcTAsP4p0Fx.
# new message created with id: msg_asXCpp1r4DTU6p44D9TO7LNV.
# run instance created with id: run_132nN1Hn5Q4addTZw3RYnfK9.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# Document 2 done.
# new thread created with id: thread_6al2vlB0A7tKY6C7w7Qm0O9j.
# new message created with id: msg_WmBXKIAZUA7cs3n3C6W2OPQj.
# run instance created with id: run_EAW03PJYvoSf9b8o0yT8cef1.
# run status: .
# run status: in_progress.
# Document 3 done.
# new thread created with id: thread_WoktxSR4ABaEL1Fa21vWQrhG.
# new message created with id: msg_sSeaobHyKfxAQrWRDbd34Nk3.
# run instance created with id: run_g09XQ1Y7tNfJnQ5zQQ32JFSX.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# Document 4 done.
# Prompt 7 done.
# new thread created with id: thread_Xo5qLPBJJgW7dYUHFQokZJRq.
# new message created with id: msg_Sw4TbxvapN9OsKN0pYOaqMem.
# run instance created with id: run_2lwTigUnqeCSKUpjiVZgZXDX.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# Document 0 done.
# new thread created with id: thread_XfocYtfxaKCbUJhL5TAfX6Bx.
# new message created with id: msg_xVI7q0eQczwX9oXT8YLGG8Mk.
# run instance created with id: run_OzOwgXlCHpZ0lRT85An1IeOx.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# Document 1 done.
# new thread created with id: thread_lvpFpUVyoH8EF04n3V6X7cV4.
# new message created with id: msg_O82y63LLFAD8pl86f28U8ei4.
# run instance created with id: run_Dac2wUmxvq3CY0fJdABGGRRd.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# Document 2 done.
# new thread created with id: thread_0GngK3xxUJjYBcnBDnqPOUF6.
# new message created with id: msg_0nDNOeo3w5lPHxYcW88wDTLR.
# run instance created with id: run_RcL4c4TMnPy52Zw5vj6y9RU9.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# Document 3 done.
# new thread created with id: thread_lnFolhrltvGm0arqLDZ3Nnw2.
# new message created with id: msg_QEpL1ZsdGNIcEqXZMuDbz4Rn.
# run instance created with id: run_tqeyfFwBZnOugVYX7BHSo6ZT.
# run status: .
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# run status: in_progress.
# Document 4 done.
# Prompt 8 done.
#   prompt document                                             result
# 0      0        0  {'Eddi Leemann': [('Role', 'Delegate of the In...
# 0      0        1  {"Manuel Contreras Sepulveda": [("Role", "Dire...
# 0      0        2  Step 1 - Document Summary:\nThe document appea...
# 0      0        3  Given the lack of specific people involved in ...
# 0      0        4  {'Gregorio Bravo Ponce de Leon': [('Role in pr...
# 0      1        0  {'Eddi Leemann': [('Visited Puchuncaví detenti...
# 0      1        1  {'Julio Arturo Acosta Georges': [('Arrested by...
# 0      1        2  {'Jorge GONZALEZ Morales': [('Condition', 'Oti...
# 0      1        3  The provided document does not contain specifi...
# 0      1        4  {'Gregorio BRAVO Ponce de Leon': [('Role', 'Me...
# 0      2        0  {'Eddi Leemann': [('Visited Puchuncaví detenti...
# 0      2        1  {'ACOSTA GEORGES JULIO ARTURO': [('Arrests', [...
# 0      2        2  {'Jorge GONZALEZ Morales': [('Health Condition...
# 0      2        3  The provided document does not contain any spe...
# 0      2        4  {'Gregorio Bravo Ponce de Leon': [('Role', 'Me...
# 0      3        0  DOCUMENT SUMMARY:\n\nThe document recounts a v...
# 0      3        1  DOCUMENT SUMMARY:\nThe document is an official...
# 0      3        2  DOCUMENT CLEANED AND SUMMARIZED:\nThe document...
# 0      3        3  The document is a formal communication from th...
# 0      3        4  The document pertains to the living conditions...
# 0      4        0  {'Gonzalo Durán Paredes': [('Position', 'Lieut...
# 0      4        1  {'Manuel Contreras Sepulveda': [('Identity', '...
# 0      4        2  {'Jorge Gonzalez Morales': [('Health Condition...
# 0      4        3  Given the provided document, it seems there's ...
# 0      4        4  {'Gregorio BRAVO Ponce de Leon': [('Role', 'Me...
# 0      5        0  DOCUMENT SUMMARY:\nThe document is an extract ...
# 0      5        1  DOCUMENT:\n\n- The document seems to be a comb...
# 0      5        2  DOCUMENT SUMMARY:\n\nThe document describes th...
# 0      5        3  The document seems to be an official correspon...
# 0      5        4  DOCUMENT SUMMARY:\nThis document describes the...
# 0      6        0  {'Gonzalo Durán Paredes':{'Position':'Lieutena...
# 0      6        1  {'Manuel Contreras Sepulveda': [('Position', '...
# 0      6        2  {'Jorge GONZALEZ Morales':[('Medical condition...
# 0      6        3  The document provided does not contain suffici...
# 0      6        4  {'Gregorio Bravo Ponce de Leon': [('Role', 'Me...
# 0      7        0  {"Gonzalo Durán Paredes": [("Role", "Responsib...
# 0      7        1  {'Manuel Contreras Sepulveda': [('Position', '...
# 0      7        2  {'Jorge GONZALEZ Morales': [('Health Condition...
# 0      7        3  The provided document does not contain specifi...
# 0      7        4  {'Gregorio Bravo Ponce de Leon': [('Role and a...
# 0      8        0  RESPONSE FORMAT:\n{'Eddi Leemann': [('Role', '...
# 0      8        1  {'Manuel Contreras Sepulveda': \n    [( 'Posit...
# 0      8        2  Step 1 - Clean the Document and Summarize it:\...
# 0      8        3  The document is an official communication from...
# 0      8        4  {'Gregorio Bravo Ponce de Leon': [('Position',...

# %%
df_results.to_csv('results.csv')
